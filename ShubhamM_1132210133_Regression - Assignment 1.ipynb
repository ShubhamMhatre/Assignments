# %% [markdown]
# # Shubham Mhatre
# # 1132210133
# # Rregression Assignmet 1

# %% [markdown]
# # This assignment carries 30 marks. Understand the distribution of the marks - question wise and solve accordingly.

# %% [markdown]
# #### Import the required libraries.

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# #### sklearn library has some inbuilt datasets. We will use the dataset 'Boston'. For that, run the below code to get the dataframe. In this dataframe, 'price' is the target variable.

# %%
from sklearn.datasets import load_boston 
boston = load_boston()
df = pd.DataFrame(boston.data,columns=boston.feature_names)
df['price'] = boston.target
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %% [markdown]
# #### 1) Check if any column has null values. (2m)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# price      0
# dtype: int64

# %% [markdown]
# #### 2) Get all the records where price is greater than 25.000 and store them in df1 (2m)

# %%
df1 = df[df['price']>2500]
df1
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, price]
# Index: []

# %% [markdown]
# #### 3) Get all the records where price is in between 25.000 and 40.000 and store them in df2 (2m)

# %%
df2 = df[(df['price']>=25.000) & (df['price']<= 40.000) ]
df2
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 365   4.55587   0.0  18.10   0.0  0.718  3.561   87.9  1.6132  24.0  666.0
# 407  11.95110   0.0  18.10   0.0  0.659  5.608  100.0  1.2852  24.0  666.0
# 409  14.43830   0.0  18.10   0.0  0.597  6.852  100.0  1.4655  24.0  666.0
# 473   4.64689   0.0  18.10   0.0  0.614  6.980   67.6  2.5329  24.0  666.0
# 482   5.73116   0.0  18.10   0.0  0.532  7.061   77.0  3.4106  24.0  666.0
#
#      PTRATIO       B  LSTAT  price
# ...

# %% [markdown]
# #### 4) Get all the records where price is less than 20.00 or price is greater than 35.00 and store them in df3 (2m)

# %%
df3 = df[(df['price']<20.00) | (df['price']<35.00)]
df3
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# ...

# %% [markdown]
# #### 5) Get the 5 point summary i.e. min, max, mean, count and std(standard deviation) of all the numerical columns. (2m)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# #### 6)The 'CHAS' column has only two unique entries, 0 and 1 and It is very like to be a categorical column. Change the datatype of this column from float to object.(2m)

# %%
print(df.dtypes)
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# price      float64
# dtype: object

# %% [markdown]
# #### 7) Calculate the groupwise average price for the "CHAS" column (2m)

# %%
df.groupby('CHAS').mean()
# Out:
#           CRIM         ZN      INDUS       NOX        RM        AGE       DIS  \
# CHAS
# 0.0   3.744447  11.634820  11.019193  0.551817  6.267174  67.911677  3.851915
# 1.0   1.851670   7.714286  12.719143  0.593426  6.519600  77.500000  3.029709
#
#            RAD         TAX    PTRATIO           B      LSTAT      price
# CHAS
# 0.0   9.566879  409.870488  18.527176  355.461040  12.757941  22.093843
# 1.0   9.314286  386.257143  17.491429  372.997429  11.241714  28.440000

# %% [markdown]
# #### 8) Visualize the proportion of categories in the column 'CHAS' (i.e. of zeros and ones) using pieplot. Also write down the interpretation of the graph.  (3m)

# %%
x = np.array(df['CHAS'])
x
no_zeros = x[np.where(x==0)]
a= no_zeros.size
no_ones = x[np.where(x==1)]
b= no_ones.size
k=np.array([a,b])
label = ['Zeros','Ones']
plt.pie(k,labels=label)
plt.legend(title = 'CHAS')
plt.show()

# %% [markdown]
# #### 9) Plot the countplot using Seaborn library for the column 'CHAS'. Write down the interpretation of the graph. (3m)

# %%
sns.countplot( x='CHAS' , data = df)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='count'>

# %% [markdown]
# #### 10) Get the correlation matrix, Also visualize it with heatmap and write appropriate conclusions. (4m)

# %%
c = df.corr()
sns.heatmap(c,annot=True , linewidths = 0.5 , annot_kws = {'size' : 7})
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 11) Separate the target variable from independent variables and store it in y. Store independent variables in x. (3m)

# %%
x  = df.loc[:,df.columns != 'CHAS']
y  = df['CHAS']
x
# Out:
#         CRIM    ZN  INDUS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0    0.00632  18.0   2.31  0.538  6.575  65.2  4.0900  1.0  296.0     15.3
# 1    0.02731   0.0   7.07  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2    0.02729   0.0   7.07  0.469  7.185  61.1  4.9671  2.0  242.0     17.8
# 3    0.03237   0.0   2.18  0.458  6.998  45.8  6.0622  3.0  222.0     18.7
# 4    0.06905   0.0   2.18  0.458  7.147  54.2  6.0622  3.0  222.0     18.7
# ..       ...   ...    ...    ...    ...   ...     ...  ...    ...      ...
# 501  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786  1.0  273.0     21.0
# 502  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875  1.0  273.0     21.0
# 503  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675  1.0  273.0     21.0
# 504  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889  1.0  273.0     21.0
# 505  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050  1.0  273.0     21.0
#
#           B  LSTAT  price
# 0    396.90   4.98   24.0
# ...

# %% [markdown]
# #### 12) Split the data into train and test, take 20% of the data in test. (3m)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
x_train
# Out:
#          CRIM    ZN  INDUS    NOX     RM   AGE     DIS   RAD    TAX  PTRATIO  \
# 220   0.35809   0.0   6.20  0.507  6.951  88.5  2.8617   8.0  307.0     17.4
# 71    0.15876   0.0  10.81  0.413  5.961  17.5  5.2873   4.0  305.0     19.2
# 240   0.11329  30.0   4.93  0.428  6.897  54.3  6.3361   6.0  300.0     16.6
# 6     0.08829  12.5   7.87  0.524  6.012  66.6  5.5605   5.0  311.0     15.2
# 417  25.94060   0.0  18.10  0.679  5.304  89.1  1.6475  24.0  666.0     20.2
# ..        ...   ...    ...    ...    ...   ...     ...   ...    ...      ...
# 323   0.28392   0.0   7.38  0.493  5.708  74.3  4.7211   5.0  287.0     19.6
# 192   0.08664  45.0   3.44  0.437  7.178  26.3  6.4798   5.0  398.0     15.2
# 117   0.15098   0.0  10.01  0.547  6.021  82.6  2.7474   6.0  432.0     17.8
# 47    0.22927   0.0   6.91  0.448  6.030  85.5  5.6894   3.0  233.0     17.9
# 172   0.13914   0.0   4.05  0.510  5.572  88.5  2.5961   5.0  296.0     16.6
#
#           B  LSTAT  price
# ...
