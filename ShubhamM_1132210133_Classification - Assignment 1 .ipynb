# %% [markdown]
# ## Shubham Mhatre
# ## 1132210133
# ## Clasification Assignment

# %% [markdown]
# # This assignment carries 30 marks. Understand the distribution of the marks - question wise and solve accordingly.

# %% [markdown]
# #### This dataset is about Diabetes disease. We want to predict whether a particular person has diabetes or not, based on the features like Insulin, Glucose etc. "Outcome" is the target variable. 1 denoting he/she has diabetes and 0 denotes he/she does not have diabetes. The task is to perform simple EDA.

# %% [markdown]
# #### Import the necessary libraries.

# %%
import pandas as pd  
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# #### 1) Read the dataset diabetes and print the first 5 rows. (2m)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# #### 2) Find the number of rows and number of columns in the dataframe. (1m)

# %%
print("Number of rows in the df =",len(df.axes[0]))
print("Number of columns in the df =",len(df.axes[1]))
# Out:
# Number of rows in the df = 768
# Number of columns in the df = 9

# %% [markdown]
# #### 3) Get the number of missing values per column. (1m)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# #### 4) Check the datatype of every column in the dataset. Change the datatype if needed. (1m)

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# #### 5) For the classes in target variable i.e. 0 and 1 here, find out an average groupwise Insulin, i.e. find out the average Insulin value for class 0 and same for class 1.(3m)

# %% [markdown]
# ###### Note : Here consider Outcome as a categorical variable even though its datatype it int.

# %%
df.groupby('Outcome')['Insulin'].mean()
# Out:
# Outcome
# 0     68.792000
# 1    100.335821
# Name: Insulin, dtype: float64

# %% [markdown]
# #### 6) Sort the dataframe original dataframe w.r.t. the column 'Glucose' in descending order and store it in a new dataframe say df_sort.(3m)

# %%
gl = pd.DataFrame(df, columns=['Pregnancies','Glucose' ,'BloodPressure',' SkinThickness' ,'Insulin' ,'BMI','DiabetesPedigreeFunction', 'Age'])
a = gl.sort_values(by = 'Glucose', ascending=False)
a
# Out:
#      Pregnancies  Glucose  BloodPressure   SkinThickness  Insulin   BMI  \
# 661            1      199             76             NaN        0  42.9
# 561            0      198             66             NaN      274  41.3
# 228            4      197             70             NaN      744  36.7
# 8              2      197             70             NaN      543  30.5
# 579            2      197             70             NaN        0  34.7
# ..           ...      ...            ...             ...      ...   ...
# 342            1        0             68             NaN        0  32.0
# 349            5        0             80             NaN        0  41.0
# 502            6        0             68             NaN        0  39.0
# 182            1        0             74             NaN       23  27.7
# 75             1        0             48             NaN        0  24.7
#
#      DiabetesPedigreeFunction  Age
# 661                     1.394   22
# ...

# %% [markdown]
# #### 7) Separate the independent columns from the original dataframe i.e. from df and store them in a new dataframe say df1. (1m)

# %%
df_new = df.copy(deep=True)
df_new.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y = df_new['Outcome']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
df1 = df_new.drop('Outcome',axis=1)
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %% [markdown]
# #### 8) Separate the target variable i.e. 'Outcome' here from the data and store it in y.(1m)

# %%
y = df['Outcome']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# #### 9) Separate the numerical and categorical columns from df1.(1m)

# %%
import numpy as np
df_num = df.select_dtypes(include=np.number)
df_num.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df['BMI'] = df['BMI'].astype('object')
df['DiabetesPedigreeFunction'] = df['DiabetesPedigreeFunction'].astype('object')

# %%
df_cat = df.select_dtypes(include='object')
df_cat.head()
# Out:
#     BMI DiabetesPedigreeFunction
# 0  33.6                    0.627
# 1  26.6                    0.351
# 2  23.3                    0.672
# 3  28.1                    0.167
# 4  43.1                    2.288

# %% [markdown]
# #### 10) For all the numerical columns, plot the kdeplot. You can use for loop. Also, comment on the skewness of the columns based on the kdeplot. (5m)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,15))

numcol = list(df_num.columns)
a=6
b=2
c=1
for i in numcol:
    plt.subplot(a,b,c)
    sns.kdeplot(df[i])
    plt.xlabel(i)
    c=c+1
plt.tight_layout()
plt.show()

# %%
df_num.skew(axis = 0, skipna = True)
# Out:
# Pregnancies      0.901674
# Glucose          0.173754
# BloodPressure   -1.843608
# SkinThickness    0.109372
# Insulin          2.272251
# Age              1.129597
# Outcome          0.635017
# dtype: float64

# %% [markdown]
# #### 11) For the numerical columns, print the correlation matrix and also visualize the same with heatmap and comment on the same. (5m)

# %%
import pandas as pd 
import numpy as np
df_num = df.select_dtypes(np.number)
df_num.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  Age  Outcome
# 0            6      148             72             35        0   50        1
# 1            1       85             66             29        0   31        0
# 2            8      183             64              0        0   32        1
# 3            1       89             66             23       94   21        0
# 4            0      137             40             35      168   33        1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(30,35))
sns.heatmap(df_num.head(100),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 12) Some unusual observations are there in the data. For eg, the insulin value cannot be 0. Filter out the rows from the dataset where Insulin value is 0. (3m)

# %%
#df[df['Insulin']==0]
df.describe() 
df1 = df[df['Insulin']!=0]
df1['Insulin'].mean(),df['Insulin'].mean()
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %% [markdown]
#  #### 13) Filter out the rows from the dataset where BloodPressure value is 0. (3m)

# %%
df1 = df[df['BloodPressure'] == 0]
df1['BloodPressure'].mean(),df['BloodPressure'].mean()
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7             10      115              0              0        0  35.3
# 15             7      100              0              0        0  30.0
# 49             7      105              0              0        0   0.0
# 60             2       84              0              0        0   0.0
# 78             0      131              0              0        0  43.2
# 81             2       74              0              0        0   0.0
# 172            2       87              0             23        0  28.9
# 193           11      135              0              0        0  52.3
# 222            7      119              0              0        0  25.2
# 261            3      141              0              0        0  30.0
# 266            0      138              0              0        0  36.3
# 269            2      146              0              0        0  27.5
# ...
